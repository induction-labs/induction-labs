# %%
import pandas as pd
base_path = "gs://induction-labs/passive_data/2025-08-14/reprocess_all_no_loading-04-30-15/".rstrip("/")
df = pd.read_json(f"{base_path}/samples.jsonl", lines=True)
df
# Out:
#        attempt_id  eval_task_id  \
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 1    ysBGeJaIcIg0  ysBGeJaIcIg0
# 2    WM1VRv1ZGWA0  WM1VRv1ZGWA0
# 3    4NhwPtQL8ePo  4NhwPtQL8ePo
# 4    T34h7cPwrGwd  T34h7cPwrGwd
# ..            ...           ...
# 672  SBYyzRpCFX2T  SBYyzRpCFX2T
# 673  v6D59d7Dpymt  v6D59d7Dpymt
# 674  6jVs1SHFLU1B  6jVs1SHFLU1B
# 675  HahLlXsiEkeV  HahLlXsiEkeV
# 676  ixVnKchUDibi  ixVnKchUDibi
#
#                                                actions  \
# 0    [click(start_box='(687,0)'), click(start_box='...
# 1    [click(start_box='(762,0)'), click(start_box='...
# 2    [click(start_box='(1559,227)'), scroll(directi...
# 3    [click(start_box='(657,629)'), hotkey(key='z',...
# 4    [click(start_box='(569,0)'), click(start_box='...
# ..                                                 ...
# 672  [type(content=''), click(start_box='(1004,918...
# 673  [type(content='\n'), hotkey(key='t', modifiers...
# 674  [hotkey(key='a', modifiers='ctrl'), click(star...
# 675  [type(content='Time'), click(start_box='(988,4...
# 676  [type(content='lxjjjo}'), type(content='kkkko'...
#
#                                               thinking  \
# 0    [The deals list is still in the foreground, an...
# 1    [The browser is still on the ChatGPT share pag...
# 2    [The GPU.net deal page is open; pricing detail...
# 3    [The Notion page shows the Outbound list, and ...
# 4    [The SFCompute “Getting started” doc is open, ...
# ..                                                 ...
# 672  [The Notion page is still open, and the cursor...
# 673  [The diff is ready and the integrated terminal...
# 674  [LibreOffice Writer is open with the file disp...
# 675  [The Options window is open to “Basic Fonts (W...
# 676  [Just under the Report Infeasible </button> I ...
#
#                                            instruction  trajectory_length  \
# 0    On the YC Bookface website, navigate to the De...                  6
# 1    1. In Chrome, switch from the ChatGPT tab to t...                  6
# 2    1. In your browser, open bookface.ycombinator....                  6
# 3    Open Notion and go to the page titled “Q2-25 R...                  6
# 4    In Google Chrome, review the documentation on ...                  6
# ..                                                 ...                ...
# 672  Research current H100 GPU pricing for alternat...                 11
# 673  Open Visual Studio Code (with Vim key-bindings...                 11
# 674  Open the file "loa-one-time-submission-sealand...                 11
# 675  Open LibreOffice Writer and change the default...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
#
#                                             source_dir  image_turns_start  \
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 1    gs://induction-labs-data-ext/action_capture/jo...                  0
# 2    gs://induction-labs-data-ext/action_capture/jo...                  0
# 3    gs://induction-labs-data-ext/action_capture/ar...                  0
# 4    gs://induction-labs-data-ext/action_capture/jo...                  0
# ..                                                 ...                ...
# 672  gs://induction-labs-data-ext/action_capture/jo...                  0
# 673  gs://induction-labs-data-ext/action_capture/je...                  0
# 674  gs://induction-labs-data-ext/action_capture/jo...                  0
# 675  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
#
#      image_turns_end  text_turns_start  text_turns_end  unmask_last_only
# 0                  5                 0               5             False
# 1                  5                 0               5             False
# 2                  5                 0               5             False
# 3                  5                 0               5             False
# 4                  5                 0               5             False
# ..               ...               ...             ...               ...
# 672               10                 0              10             False
# 673               10                 0              10             False
# 674               10                 0              10             False
# 675               10                 0              10             False
# 676               10                 0              10             False
#
# [677 rows x 12 columns]

# %%
df['actions_with_thinking'] = df.apply(
    lambda r: list(zip(r['actions'], r['thinking'])),
    axis=1
)
df
# Out:
#        attempt_id  eval_task_id  \
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 1    ysBGeJaIcIg0  ysBGeJaIcIg0
# 2    WM1VRv1ZGWA0  WM1VRv1ZGWA0
# 3    4NhwPtQL8ePo  4NhwPtQL8ePo
# 4    T34h7cPwrGwd  T34h7cPwrGwd
# ..            ...           ...
# 672  SBYyzRpCFX2T  SBYyzRpCFX2T
# 673  v6D59d7Dpymt  v6D59d7Dpymt
# 674  6jVs1SHFLU1B  6jVs1SHFLU1B
# 675  HahLlXsiEkeV  HahLlXsiEkeV
# 676  ixVnKchUDibi  ixVnKchUDibi
#
#                                                actions  \
# 0    [click(start_box='(687,0)'), click(start_box='...
# 1    [click(start_box='(762,0)'), click(start_box='...
# 2    [click(start_box='(1559,227)'), scroll(directi...
# 3    [click(start_box='(657,629)'), hotkey(key='z',...
# 4    [click(start_box='(569,0)'), click(start_box='...
# ..                                                 ...
# 672  [type(content=''), click(start_box='(1004,918...
# 673  [type(content='\n'), hotkey(key='t', modifiers...
# 674  [hotkey(key='a', modifiers='ctrl'), click(star...
# 675  [type(content='Time'), click(start_box='(988,4...
# 676  [type(content='lxjjjo}'), type(content='kkkko'...
#
#                                               thinking  \
# 0    [The deals list is still in the foreground, an...
# 1    [The browser is still on the ChatGPT share pag...
# 2    [The GPU.net deal page is open; pricing detail...
# 3    [The Notion page shows the Outbound list, and ...
# 4    [The SFCompute “Getting started” doc is open, ...
# ..                                                 ...
# 672  [The Notion page is still open, and the cursor...
# 673  [The diff is ready and the integrated terminal...
# 674  [LibreOffice Writer is open with the file disp...
# 675  [The Options window is open to “Basic Fonts (W...
# 676  [Just under the Report Infeasible </button> I ...
#
#                                            instruction  trajectory_length  \
# 0    On the YC Bookface website, navigate to the De...                  6
# 1    1. In Chrome, switch from the ChatGPT tab to t...                  6
# 2    1. In your browser, open bookface.ycombinator....                  6
# 3    Open Notion and go to the page titled “Q2-25 R...                  6
# 4    In Google Chrome, review the documentation on ...                  6
# ..                                                 ...                ...
# 672  Research current H100 GPU pricing for alternat...                 11
# 673  Open Visual Studio Code (with Vim key-bindings...                 11
# 674  Open the file "loa-one-time-submission-sealand...                 11
# 675  Open LibreOffice Writer and change the default...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
#
#                                             source_dir  image_turns_start  \
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 1    gs://induction-labs-data-ext/action_capture/jo...                  0
# 2    gs://induction-labs-data-ext/action_capture/jo...                  0
# 3    gs://induction-labs-data-ext/action_capture/ar...                  0
# 4    gs://induction-labs-data-ext/action_capture/jo...                  0
# ..                                                 ...                ...
# 672  gs://induction-labs-data-ext/action_capture/jo...                  0
# 673  gs://induction-labs-data-ext/action_capture/je...                  0
# 674  gs://induction-labs-data-ext/action_capture/jo...                  0
# 675  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
#
#      image_turns_end  text_turns_start  text_turns_end  unmask_last_only  \
# 0                  5                 0               5             False
# 1                  5                 0               5             False
# 2                  5                 0               5             False
# 3                  5                 0               5             False
# 4                  5                 0               5             False
# ..               ...               ...             ...               ...
# 672               10                 0              10             False
# 673               10                 0              10             False
# 674               10                 0              10             False
# 675               10                 0              10             False
# 676               10                 0              10             False
#
#                                  actions_with_thinking
# 0    [(click(start_box='(687,0)'), The deals list i...
# 1    [(click(start_box='(762,0)'), The browser is s...
# 2    [(click(start_box='(1559,227)'), The GPU.net d...
# 3    [(click(start_box='(657,629)'), The Notion pag...
# 4    [(click(start_box='(569,0)'), The SFCompute “G...
# ..                                                 ...
# 672  [(type(content=''), The Notion page is still ...
# 673  [(type(content='\n'), The diff is ready and th...
# 674  [(hotkey(key='a', modifiers='ctrl'), LibreOffi...
# 675  [(type(content='Time'), The Options window is ...
# 676  [(type(content='lxjjjo}'), Just under the Repo...
#
# [677 rows x 13 columns]

# %%
out = (
    df.assign(action_index=df['actions_with_thinking'].apply(lambda x: list(range(len(x)))))
      .explode(['actions_with_thinking', 'action_index'], ignore_index=False)   # use True if you want a fresh RangeIndex
)
out
# Out:
#        attempt_id  eval_task_id  \
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# ..            ...           ...
# 676  ixVnKchUDibi  ixVnKchUDibi
# 676  ixVnKchUDibi  ixVnKchUDibi
# 676  ixVnKchUDibi  ixVnKchUDibi
# 676  ixVnKchUDibi  ixVnKchUDibi
# 676  ixVnKchUDibi  ixVnKchUDibi
#
#                                                actions  \
# 0    [click(start_box='(687,0)'), click(start_box='...
# 0    [click(start_box='(687,0)'), click(start_box='...
# 0    [click(start_box='(687,0)'), click(start_box='...
# 0    [click(start_box='(687,0)'), click(start_box='...
# 0    [click(start_box='(687,0)'), click(start_box='...
# ..                                                 ...
# 676  [type(content='lxjjjo}'), type(content='kkkko'...
# 676  [type(content='lxjjjo}'), type(content='kkkko'...
# 676  [type(content='lxjjjo}'), type(content='kkkko'...
# 676  [type(content='lxjjjo}'), type(content='kkkko'...
# 676  [type(content='lxjjjo}'), type(content='kkkko'...
#
#                                               thinking  \
# 0    [The deals list is still in the foreground, an...
# 0    [The deals list is still in the foreground, an...
# 0    [The deals list is still in the foreground, an...
# 0    [The deals list is still in the foreground, an...
# 0    [The deals list is still in the foreground, an...
# ..                                                 ...
# 676  [Just under the Report Infeasible </button> I ...
# 676  [Just under the Report Infeasible </button> I ...
# 676  [Just under the Report Infeasible </button> I ...
# 676  [Just under the Report Infeasible </button> I ...
# 676  [Just under the Report Infeasible </button> I ...
#
#                                            instruction  trajectory_length  \
# 0    On the YC Bookface website, navigate to the De...                  6
# 0    On the YC Bookface website, navigate to the De...                  6
# 0    On the YC Bookface website, navigate to the De...                  6
# 0    On the YC Bookface website, navigate to the De...                  6
# 0    On the YC Bookface website, navigate to the De...                  6
# ..                                                 ...                ...
# 676  Open VS Code and load the file `frontend/src/a...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
#
#                                             source_dir  image_turns_start  \
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# ..                                                 ...                ...
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
#
#      image_turns_end  text_turns_start  text_turns_end  unmask_last_only  \
# 0                  5                 0               5             False
# 0                  5                 0               5             False
# 0                  5                 0               5             False
# 0                  5                 0               5             False
# 0                  5                 0               5             False
# ..               ...               ...             ...               ...
# 676               10                 0              10             False
# 676               10                 0              10             False
# 676               10                 0              10             False
# 676               10                 0              10             False
# 676               10                 0              10             False
#
#                                  actions_with_thinking action_index
# 0    (click(start_box='(687,0)'), The deals list is...            0
# 0    (click(start_box='(521,0)'), The Lambda detail...            1
# 0    (scroll(direction='up', start_box='(563,335)')...            2
# 0    (drag(start_box='(744,348)', end_box='(577,341...            3
# 0    (type(content='AWS'), The search field in the ...            4
# ..                                                 ...          ...
# 676  (type(content='bbbbbbwwi!'), Next, I need to p...            6
# 676  (type(content='bbbvwwwwwwbbbhx$b'), On the new...            7
# 676  (hotkey(key='s', modifiers='cmd'), The guard e...            8
# 676  (scroll(direction='up', start_box='(588,465)')...            9
# 676                                     (finished(), )           10
#
# [6783 rows x 14 columns]

# %%
out['actions'] = out['actions_with_thinking'].apply(lambda x: x[0])
out['thinking'] = out['actions_with_thinking'].apply(lambda x: x[1])
out = out.drop(columns=['actions_with_thinking'])
out
# Out:
#        attempt_id  eval_task_id  \
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# ..            ...           ...
# 676  ixVnKchUDibi  ixVnKchUDibi
# 676  ixVnKchUDibi  ixVnKchUDibi
# 676  ixVnKchUDibi  ixVnKchUDibi
# 676  ixVnKchUDibi  ixVnKchUDibi
# 676  ixVnKchUDibi  ixVnKchUDibi
#
#                                               actions  \
# 0                          click(start_box='(687,0)')
# 0                          click(start_box='(521,0)')
# 0       scroll(direction='up', start_box='(563,335)')
# 0    drag(start_box='(744,348)', end_box='(577,341)')
# 0                                 type(content='AWS')
# ..                                                ...
# 676                        type(content='bbbbbbwwi!')
# 676                 type(content='bbbvwwwwwwbbbhx$b')
# 676                  hotkey(key='s', modifiers='cmd')
# 676     scroll(direction='up', start_box='(588,465)')
# 676                                        finished()
#
#                                               thinking  \
# 0    The deals list is still in the foreground, and...
# 0    The Lambda details page is open; the banner at...
# 0    I’m back on the Deals list, but I’m halfway do...
# 0    The search field in the top-center now shows t...
# 0    The search field in the top-center is active a...
# ..                                                 ...
# 676  Next, I need to perform this action: type(cont...
# 676  On the new line I can still see the stray segm...
# 676  The guard expression now reads exactly "peekQu...
# 676  The guard line is in place, the white dot on t...
# 676
#
#                                            instruction  trajectory_length  \
# 0    On the YC Bookface website, navigate to the De...                  6
# 0    On the YC Bookface website, navigate to the De...                  6
# 0    On the YC Bookface website, navigate to the De...                  6
# 0    On the YC Bookface website, navigate to the De...                  6
# 0    On the YC Bookface website, navigate to the De...                  6
# ..                                                 ...                ...
# 676  Open VS Code and load the file `frontend/src/a...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
#
#                                             source_dir  image_turns_start  \
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# ..                                                 ...                ...
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
#
#      image_turns_end  text_turns_start  text_turns_end  unmask_last_only  \
# 0                  5                 0               5             False
# 0                  5                 0               5             False
# 0                  5                 0               5             False
# 0                  5                 0               5             False
# 0                  5                 0               5             False
# ..               ...               ...             ...               ...
# 676               10                 0              10             False
# 676               10                 0              10             False
# 676               10                 0              10             False
# 676               10                 0              10             False
# 676               10                 0              10             False
#
#     action_index
# 0              0
# 0              1
# 0              2
# 0              3
# 0              4
# ..           ...
# 676            6
# 676            7
# 676            8
# 676            9
# 676           10
#
# [6783 rows x 13 columns]

# %%
out.to_json(f"{base_path}/samples_actions_explode.jsonl", orient='records', lines=True)

# %%
df_only_click = out[out['actions'].apply(lambda x: x.startswith(('click', 'left_double', 'right_single', 'drag')))]
df_only_click
# Out:
#        attempt_id  eval_task_id  \
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 0    3RPNEpUpBt8B  3RPNEpUpBt8B
# 1    ysBGeJaIcIg0  ysBGeJaIcIg0
# 1    ysBGeJaIcIg0  ysBGeJaIcIg0
# ..            ...           ...
# 675  HahLlXsiEkeV  HahLlXsiEkeV
# 675  HahLlXsiEkeV  HahLlXsiEkeV
# 675  HahLlXsiEkeV  HahLlXsiEkeV
# 676  ixVnKchUDibi  ixVnKchUDibi
# 676  ixVnKchUDibi  ixVnKchUDibi
#
#                                               actions  \
# 0                          click(start_box='(687,0)')
# 0                          click(start_box='(521,0)')
# 0    drag(start_box='(744,348)', end_box='(577,341)')
# 1                          click(start_box='(762,0)')
# 1                        click(start_box='(722,672)')
# ..                                                ...
# 675                     click(start_box='(1048,823)')
# 675                    click(start_box='(1143,1054)')
# 675                    click(start_box='(1276,1070)')
# 676  drag(start_box='(498,528)', end_box='(589,528)')
# 676                      click(start_box='(588,465)')
#
#                                               thinking  \
# 0    The deals list is still in the foreground, and...
# 0    The Lambda details page is open; the banner at...
# 0    The search field in the top-center now shows t...
# 1    The browser is still on the ChatGPT share page...
# 1    The Notion page is already scrolled to the “Ot...
# ..                                                 ...
# 675  The Options – LibreOffice Writer dialog is sti...
# 675  The Options dialog in the center still lists “...
# 675  The green banner near the top confirms the aut...
# 676  The new empty line I opened is visible just un...
# 676  I can see the empty line I opened just below t...
#
#                                            instruction  trajectory_length  \
# 0    On the YC Bookface website, navigate to the De...                  6
# 0    On the YC Bookface website, navigate to the De...                  6
# 0    On the YC Bookface website, navigate to the De...                  6
# 1    1. In Chrome, switch from the ChatGPT tab to t...                  6
# 1    1. In Chrome, switch from the ChatGPT tab to t...                  6
# ..                                                 ...                ...
# 675  Open LibreOffice Writer and change the default...                 11
# 675  Open LibreOffice Writer and change the default...                 11
# 675  Open LibreOffice Writer and change the default...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
# 676  Open VS Code and load the file `frontend/src/a...                 11
#
#                                             source_dir  image_turns_start  \
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 0    gs://induction-labs-data-ext/action_capture/jo...                  0
# 1    gs://induction-labs-data-ext/action_capture/jo...                  0
# 1    gs://induction-labs-data-ext/action_capture/jo...                  0
# ..                                                 ...                ...
# 675  gs://induction-labs-data-ext/action_capture/jo...                  0
# 675  gs://induction-labs-data-ext/action_capture/jo...                  0
# 675  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
# 676  gs://induction-labs-data-ext/action_capture/jo...                  0
#
#      image_turns_end  text_turns_start  text_turns_end  unmask_last_only  \
# 0                  5                 0               5             False
# 0                  5                 0               5             False
# 0                  5                 0               5             False
# 1                  5                 0               5             False
# 1                  5                 0               5             False
# ..               ...               ...             ...               ...
# 675               10                 0              10             False
# 675               10                 0              10             False
# 675               10                 0              10             False
# 676               10                 0              10             False
# 676               10                 0              10             False
#
#     action_index
# 0              0
# 0              1
# 0              3
# 1              0
# 1              1
# ..           ...
# 675            7
# 675            8
# 675            9
# 676            2
# 676            3
#
# [2877 rows x 13 columns]

# %%
df_only_click.to_json(f"{base_path}/samples_actions_explode_only_click.jsonl", orient='records', lines=True)

# %%
from smart_open import open as smart_open
import json
from synth.recordings.gemini_process import SaveAction


def load_item(source_dir: str, attempt_id: str, index: int) -> SaveAction:
  source_dir = source_dir.rstrip("/")
  with smart_open(f"{source_dir}/metadata/{attempt_id}.json", "r") as f:
    items = json.load(f)
    assert isinstance(items, list)
  return SaveAction.model_validate(items[index])

# %%
row = df_only_click.iloc[4]
item = load_item(base_path, row['attempt_id'], row['action_index'])
item
# Out:
# SaveAction(step=0, image='...', action="click(start_box='(687,0)')", text="Thought: The deals list is still in the foreground, and I don’t see the Lambda offer on the current scroll position. I notice a Bookface tab near the middle of the tab strip that I opened for Lambda earlier. To view the Lambda details and verify its cloud-credit offers, I’ll click that tab to bring it into focus.\nAction: click(start_box='(687,0)')", thinking='The deals list is still in the foreground, and I don’t see the Lambda offer on the current scroll position. I notice a Bookface tab near the middle of the tab strip that I opened for Lambda earlier. To view the Lambda details and verify its cloud-credit offers, I’ll click that tab to bring it into focus.', reward=1.0, frame_metadata=FrameMetadata(timestamp=1751642635.6333334, original_timestamp=1751642635.6136048, video_path='gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF/screen_capture_000044.mp4'))

# %%
item.thinking
# Out:
# 'The deals list is still in the foreground, and I don’t see the Lambda offer on the current scroll position. I notice a Bookface tab near the middle of the tab strip that I opened for Lambda earlier. To view the Lambda details and verify its cloud-credit offers, I’ll click that tab to bring it into focus.'

# %%
base_path = base_path.rstrip("/")

# %%
k = df_only_click.to_dict(orient='records')
k
# Out:
# [{'attempt_id': '3RPNEpUpBt8B',
#   'eval_task_id': '3RPNEpUpBt8B',
#   'actions': "click(start_box='(687,0)')",
#   'thinking': 'The deals list is still in the foreground, and I don’t see the Lambda offer on the current scroll position. I notice a Bookface tab near the middle of the tab strip that I opened for Lambda earlier. To view the Lambda details and verify its cloud-credit offers, I’ll click that tab to bring it into focus.',
#   'instruction': 'On the YC Bookface website, navigate to the Deals section and: \n1. Use the search bar to look for deals containing the keyword “compute.”\n2. From the results, open the Lambda deal to review its details and available cloud-credit offers.\n3. After reviewing, return to the main Deals list.\n4. Clear the previous search term by selecting it in the search bar and type “AWS” to see all AWS-related deals available to YC founders.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': '3RPNEpUpBt8B',
#   'eval_task_id': '3RPNEpUpBt8B',
#   'actions': "click(start_box='(521,0)')",
#   'thinking': 'The Lambda details page is open; the banner at the top shows the company name and I can see the cloud-credit tiers in the middle of the page, so I’ve verified the offer. To get back to the full Deals list, the easiest way is to switch to the tab where I ran the original “compute” search—the Bookface tab just to the left in the tab bar. I’ll click that left-side tab in the top row to return to the filtered results view.',
#   'instruction': 'On the YC Bookface website, navigate to the Deals section and: \n1. Use the search bar to look for deals containing the keyword “compute.”\n2. From the results, open the Lambda deal to review its details and available cloud-credit offers.\n3. After reviewing, return to the main Deals list.\n4. Clear the previous search term by selecting it in the search bar and type “AWS” to see all AWS-related deals available to YC founders.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 1},
#  {'attempt_id': '3RPNEpUpBt8B',
#   'eval_task_id': '3RPNEpUpBt8B',
#   'actions': "drag(start_box='(744,348)', end_box='(577,341)')",
#   'thinking': 'The search field in the top-center now shows the word “compute,” and the list below is filtered to 15 deals. To replace this keyword, I need the whole word selected first. I’ll drag from the right edge of the word back to the left inside the search box so the entire term is highlighted and ready to be overwritten with “AWS.”',
#   'instruction': 'On the YC Bookface website, navigate to the Deals section and: \n1. Use the search bar to look for deals containing the keyword “compute.”\n2. From the results, open the Lambda deal to review its details and available cloud-credit offers.\n3. After reviewing, return to the main Deals list.\n4. Clear the previous search term by selecting it in the search bar and type “AWS” to see all AWS-related deals available to YC founders.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 3},
#  {'attempt_id': 'ysBGeJaIcIg0',
#   'eval_task_id': 'ysBGeJaIcIg0',
#   'actions': "click(start_box='(762,0)')",
#   'thinking': 'The browser is still on the ChatGPT share page, but the price update I need to make is in the Notion doc. I see the tab titled “GPU Compute Deals/Pricing” sitting in the middle of the tab bar at the top. That’s the workspace where the bullet list lives, so I’ll click that tab now to bring the Notion page into view.',
#   'instruction': '1. In Chrome, switch from the ChatGPT tab to the open Notion tab titled “GPU Compute Deals/Pricing.”\n2. Scroll (if necessary) to the “Other Cloud Providers” section.\n3. Expand the nested list item for “Coreweave.”\n4. In the bullet that begins “Price per H100 hour: …,” select the existing dollar amount (currently “$12.31”).\n5. Replace it with the updated value “$6.16/hr”.\n6. Leave the rest of the bullet unchanged and make sure the new price is saved.\n7. Click back to the ChatGPT tab so you can continue reviewing the source information.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': 'ysBGeJaIcIg0',
#   'eval_task_id': 'ysBGeJaIcIg0',
#   'actions': "click(start_box='(722,672)')",
#   'thinking': 'The Notion page is already scrolled to the “Other Cloud Providers” section. I can see “Coreweave” sitting in the middle of the list with its disclosure arrow still pointing right, so its sub-bullets are hidden. I need to get to the price bullet inside that toggle. I’ll click directly on the “Coreweave” line to expand the nested items and reveal the bullet I have to edit next.',
#   'instruction': '1. In Chrome, switch from the ChatGPT tab to the open Notion tab titled “GPU Compute Deals/Pricing.”\n2. Scroll (if necessary) to the “Other Cloud Providers” section.\n3. Expand the nested list item for “Coreweave.”\n4. In the bullet that begins “Price per H100 hour: …,” select the existing dollar amount (currently “$12.31”).\n5. Replace it with the updated value “$6.16/hr”.\n6. Leave the rest of the bullet unchanged and make sure the new price is saved.\n7. Click back to the ChatGPT tab so you can continue reviewing the source information.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 1},
#  {'attempt_id': 'ysBGeJaIcIg0',
#   'eval_task_id': 'ysBGeJaIcIg0',
#   'actions': "left_double(start_box='(929,701)')",
#   'thinking': 'The Coreweave toggle is open, and I can see the first sub-bullet reading “Price per H100 hour: $12.31/hr” near the middle of the page. The only part that needs changing is the number. To overwrite it without disturbing the rest of the sentence, I’ll double-click directly on “$12.31” so the number becomes highlighted and ready for replacement.',
#   'instruction': '1. In Chrome, switch from the ChatGPT tab to the open Notion tab titled “GPU Compute Deals/Pricing.”\n2. Scroll (if necessary) to the “Other Cloud Providers” section.\n3. Expand the nested list item for “Coreweave.”\n4. In the bullet that begins “Price per H100 hour: …,” select the existing dollar amount (currently “$12.31”).\n5. Replace it with the updated value “$6.16/hr”.\n6. Leave the rest of the bullet unchanged and make sure the new price is saved.\n7. Click back to the ChatGPT tab so you can continue reviewing the source information.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 2},
#  {'attempt_id': 'ysBGeJaIcIg0',
#   'eval_task_id': 'ysBGeJaIcIg0',
#   'actions': "click(start_box='(961,0)')",
#   'thinking': 'The Notion page now shows “Price per H100 hour: $6.16/hr,” so the edit is done. I still need the reference details from ChatGPT that are open in the tab just to the right of the current one on the tab bar at the top. To bring those notes back into view, I’ll click that ChatGPT tab in the top row.',
#   'instruction': '1. In Chrome, switch from the ChatGPT tab to the open Notion tab titled “GPU Compute Deals/Pricing.”\n2. Scroll (if necessary) to the “Other Cloud Providers” section.\n3. Expand the nested list item for “Coreweave.”\n4. In the bullet that begins “Price per H100 hour: …,” select the existing dollar amount (currently “$12.31”).\n5. Replace it with the updated value “$6.16/hr”.\n6. Leave the rest of the bullet unchanged and make sure the new price is saved.\n7. Click back to the ChatGPT tab so you can continue reviewing the source information.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 4},
#  {'attempt_id': 'WM1VRv1ZGWA0',
#   'eval_task_id': 'WM1VRv1ZGWA0',
#   'actions': "click(start_box='(1559,227)')",
#   'thinking': 'The GPU.net deal page is open; pricing details fill the center, and on the right a small panel shows a blue “Show redemption instructions” button. I need those instructions visible before moving on. I’ll click that blue button at the top of the right-hand panel to reveal the redemption details.',
#   'instruction': '1. In your browser, open bookface.ycombinator.com and go to the YC Deals page for “GPU.net”. \n2. Click the blue “Show redemption instructions” button so the instructions panel appears on the right side of the page. \n3. Without leaving the Bookface tab, open a new browser tab (Ctrl + T or click the + icon). \n4. In the address bar of the new tab, type “gpu.net reviews” and press Enter to run a Google search. \n5. Review the search-results page (you should see video and article results about GPU.net) to evaluate what other users say about the service.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': 'WM1VRv1ZGWA0',
#   'eval_task_id': 'WM1VRv1ZGWA0',
#   'actions': "click(start_box='(1702,5)')",
#   'thinking': 'Everything I need on the deal page is visible now—the redemption email shows in the right panel, and I’m still on the GPU.net tab. To look up outside opinions without losing this page, I’ll open a fresh tab. The + icon at the far right of the tab bar is the quickest way, so I’ll click it to create a new blank tab.',
#   'instruction': '1. In your browser, open bookface.ycombinator.com and go to the YC Deals page for “GPU.net”. \n2. Click the blue “Show redemption instructions” button so the instructions panel appears on the right side of the page. \n3. Without leaving the Bookface tab, open a new browser tab (Ctrl + T or click the + icon). \n4. In the address bar of the new tab, type “gpu.net reviews” and press Enter to run a Google search. \n5. Review the search-results page (you should see video and article results about GPU.net) to evaluate what other users say about the service.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 2},
#  {'attempt_id': 'WM1VRv1ZGWA0',
#   'eval_task_id': 'WM1VRv1ZGWA0',
#   'actions': "drag(start_box='(1623,8)', end_box='(680,2)')",
#   'thinking': 'The Google results page for “gpu.net reviews” is loaded, and I can see several video links in the main column. My new search tab sits all the way at the far right of a long row of open tabs, while the Bookface deal tab is near the center. Jumping back and forth between two tabs that far apart will slow me down. I’ll drag the current tab leftward along the tab bar until it lands beside the Bookface tab, keeping both pages close for easy comparison.',
#   'instruction': '1. In your browser, open bookface.ycombinator.com and go to the YC Deals page for “GPU.net”. \n2. Click the blue “Show redemption instructions” button so the instructions panel appears on the right side of the page. \n3. Without leaving the Bookface tab, open a new browser tab (Ctrl + T or click the + icon). \n4. In the address bar of the new tab, type “gpu.net reviews” and press Enter to run a Google search. \n5. Review the search-results page (you should see video and article results about GPU.net) to evaluate what other users say about the service.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 4},
#  {'attempt_id': '4NhwPtQL8ePo',
#   'eval_task_id': '4NhwPtQL8ePo',
#   'actions': "click(start_box='(657,629)')",
#   'thinking': 'The Notion page shows the Outbound list, and I don’t see the text cursor anywhere. To be certain the editor has focus before I start undoing the last two edits, I’ll click on the bullet that ends with “(no hyperlinks)”, right where the recent change was made. That will put the caret in the correct list item so Cmd + Z will undo the intended content.',
#   'instruction': 'Open Notion and go to the page titled “Q2-25 Retro + Q3-25 Planning.”\n1. Press Cmd + Z twice to undo the two most recent edits so the bullet list returns to its prior state.\n2. Click at the end of the bullet that says “Last email within cadences did not drive traffic/activity (no hyperlinks).”\n3. Press Enter to create a new indented sub-bullet.\n4. Type: “No one has ever asked me to send them any of the resources – Aryan”.\n5. Press Enter once more to leave a blank line, keeping the list formatting clean.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-07_170814_A2QD2',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': '4NhwPtQL8ePo',
#   'eval_task_id': '4NhwPtQL8ePo',
#   'actions': "click(start_box='(715,626)')",
#   'thinking': 'The list has reverted, and the bullet that ends with “(no hyperlinks)” is back in place under the What didn’t work? section. To make sure the insertion point is exactly at the end of that bullet—so the next Enter will create a properly indented sub-bullet—I’ll click just after the closing parenthesis in the middle of the screen.',
#   'instruction': 'Open Notion and go to the page titled “Q2-25 Retro + Q3-25 Planning.”\n1. Press Cmd + Z twice to undo the two most recent edits so the bullet list returns to its prior state.\n2. Click at the end of the bullet that says “Last email within cadences did not drive traffic/activity (no hyperlinks).”\n3. Press Enter to create a new indented sub-bullet.\n4. Type: “No one has ever asked me to send them any of the resources – Aryan”.\n5. Press Enter once more to leave a blank line, keeping the list formatting clean.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-07_170814_A2QD2',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 3},
#  {'attempt_id': 'T34h7cPwrGwd',
#   'eval_task_id': 'T34h7cPwrGwd',
#   'actions': "click(start_box='(569,0)')",
#   'thinking': 'The SFCompute “Getting started” doc is open, and I can see the paragraph that confirms unused time can be resold. My next step is to record that note in the Notion doc. The tab labeled “GPU Compute Deals/Pricing” is a few spots to the left in the tab bar at the top of the window, so I’ll click that tab to switch over to Notion and add the sentence under the SFCompute bullet.',
#   'instruction': 'In Google Chrome, review the documentation on docs.sfcompute.com/docs/getting-started to confirm that SFCompute lets users resell unused GPU time. Next, switch to the Notion page titled “GPU Compute Deals/Pricing” (located in the Induction Labs → Document Hub workspace). Under the bullet list for the provider “SFCompute,” append the sentence “You can buy and then resell whatever you don’t use.” After adding the note, return to the SFCompute documentation tab and continue scrolling to read more details for future notes.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': 'T34h7cPwrGwd',
#   'eval_task_id': 'T34h7cPwrGwd',
#   'actions': "click(start_box='(1244,798)')",
#   'thinking': 'The Notion doc is back on-screen, showing the “Guaranteed Discounts/Deals” list, and the expanded SFCompute bullet sits midway down the page. To add my note, I first need the text cursor at the very end of the long paragraph inside that SFCompute sub-bullet. The fastest way is to click in the white space just to the right of that line—near the bottom-right edge of the window—so Notion will snap the caret to the paragraph’s end. Once the cursor appears there, I’ll type the extra sentence.',
#   'instruction': 'In Google Chrome, review the documentation on docs.sfcompute.com/docs/getting-started to confirm that SFCompute lets users resell unused GPU time. Next, switch to the Notion page titled “GPU Compute Deals/Pricing” (located in the Induction Labs → Document Hub workspace). Under the bullet list for the provider “SFCompute,” append the sentence “You can buy and then resell whatever you don’t use.” After adding the note, return to the SFCompute documentation tab and continue scrolling to read more details for future notes.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 1},
#  {'attempt_id': 'T34h7cPwrGwd',
#   'eval_task_id': 'T34h7cPwrGwd',
#   'actions': "click(start_box='(684,0)')",
#   'thinking': 'The Notion page shows my added sentence under the SFCompute bullet, so the note-taking step is done for now. I want to keep reviewing the source material, which is in the Chrome tab titled “Getting started | D...” near the center of the tab bar at the very top of the window. I’ll click that tab to bring the SFCompute documentation back into view and continue scrolling through it for any other useful points.',
#   'instruction': 'In Google Chrome, review the documentation on docs.sfcompute.com/docs/getting-started to confirm that SFCompute lets users resell unused GPU time. Next, switch to the Notion page titled “GPU Compute Deals/Pricing” (located in the Induction Labs → Document Hub workspace). Under the bullet list for the provider “SFCompute,” append the sentence “You can buy and then resell whatever you don’t use.” After adding the note, return to the SFCompute documentation tab and continue scrolling to read more details for future notes.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 3},
#  {'attempt_id': '6rMzspuVrMnN',
#   'eval_task_id': '6rMzspuVrMnN',
#   'actions': "click(start_box='(907,787)')",
#   'thinking': 'Slack is in front, showing the “induction_labs-halluminate” channel; the message history fills the center, and the empty compose box sits along the bottom edge. I need Slack to be the foreground app and the text cursor inside that compose field before I quit it. The quickest way is to click once inside the message box near the lower-right corner. That should activate the app and place the caret, setting me up to press ⌘ Q next.',
#   'instruction': 'Please switch from Slack to Google Sheets and then relaunch Slack using Spotlight:\n\n1. With Slack open, click once inside the message box of the channel “induction_labs-halluminate” (near the lower-right corner) to ensure Slack is the active application and that the cursor is placed in the compose area.\n2. Quit Slack by pressing ⌘ Q.\n3. Move to the existing Google Chrome window that has the spreadsheet "Sample Tasks" open and continue working (cell H57 is currently selected).\n4. Press ⌘ Space to open macOS Spotlight Search.\n5. Type “slack” and press ⏎ to relaunch the Slack application so you can return to your team conversation when it finishes loading.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/jonathan/2025-07-17_093647_KZ3CG',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': 'uGxndQ1RnbGs',
#   'eval_task_id': 'uGxndQ1RnbGs',
#   'actions': "click(start_box='(1246,0)')",
#   'thinking': 'The Brex expenses table is open in the main window, so I’ve confirmed the reference data I need. To start splitting the BREX reimbursement, I have to move over to the Inkle Books Transactions page. I spot the tab labeled “Transactions | Inkle” toward the right side of the browser’s tab bar, so I’ll click that tab to bring the Inkle window to the front and get to the split dialog.',
#   'instruction': 'In Google Chrome, do the following bookkeeping task:\n1. Open the Brex dashboard and keep the “Expenses” table visible so you can reference individual reimbursement lines.\n2. In a separate browser tab, open the Inkle Books “Transactions” page and locate the transaction titled “BREX INC. – BREX ReIMbursement” dated 30 Jun 2025.\n3. Click the transaction’s Split option to open the “Split Transaction” dialog.\n4. In the first split row (already populated with vendor CHIPOTLE 1102):\n   • Ensure the description reads “Chipotle”.\n   • Choose category “52820 – Working Meals”.\n   • Enter the amount $13.41.\n5. In the second split row:\n   • Set the vendor to “Clerky and Domino Rizzi”.\n   • Set the category to “52600 – Legal & Professional Fees”.\n   • Click the Amount cell and type 1541.72, then press Enter so it shows “$1,541.72”.\n6. Click the vendor drop-down in the third split row to prepare for adding another vendor allocation, but do not fill it in yet.\n7. Switch back to the Brex “Expenses” tab to review the remaining reimbursement entries that still need to be split later.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': 'uGxndQ1RnbGs',
#   'eval_task_id': 'uGxndQ1RnbGs',
#   'actions': "click(start_box='(1233,472)')",
#   'thinking': 'The Split Transaction dialog is open. In the second row, the vendor and category are filled in, but the Amount column on the far right still shows $0.00 and is highlighted with the red error text “Amount must be greater than zero.” I need to replace that placeholder with the real figure for this legal fee. To edit it, I’ll click directly on the $0.00 field in that row to put the cursor inside and make it editable.',
#   'instruction': 'In Google Chrome, do the following bookkeeping task:\n1. Open the Brex dashboard and keep the “Expenses” table visible so you can reference individual reimbursement lines.\n2. In a separate browser tab, open the Inkle Books “Transactions” page and locate the transaction titled “BREX INC. – BREX ReIMbursement” dated 30 Jun 2025.\n3. Click the transaction’s Split option to open the “Split Transaction” dialog.\n4. In the first split row (already populated with vendor CHIPOTLE 1102):\n   • Ensure the description reads “Chipotle”.\n   • Choose category “52820 – Working Meals”.\n   • Enter the amount $13.41.\n5. In the second split row:\n   • Set the vendor to “Clerky and Domino Rizzi”.\n   • Set the category to “52600 – Legal & Professional Fees”.\n   • Click the Amount cell and type 1541.72, then press Enter so it shows “$1,541.72”.\n6. Click the vendor drop-down in the third split row to prepare for adding another vendor allocation, but do not fill it in yet.\n7. Switch back to the Brex “Expenses” tab to review the remaining reimbursement entries that still need to be split later.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 1},
#  {'attempt_id': 'uGxndQ1RnbGs',
#   'eval_task_id': 'uGxndQ1RnbGs',
#   'actions': "click(start_box='(294,538)')",
#   'thinking': 'Row two now shows $1,541.72, so the error is cleared. The third row is blank—the Vendor cell on the left still says “Select,” which matches the next step of starting a new split. To get the list of vendors and set this row up, I’ll click that “Select” drop-down in the third row, left side of the dialog, opening the menu so I can pick the correct vendor next.',
#   'instruction': 'In Google Chrome, do the following bookkeeping task:\n1. Open the Brex dashboard and keep the “Expenses” table visible so you can reference individual reimbursement lines.\n2. In a separate browser tab, open the Inkle Books “Transactions” page and locate the transaction titled “BREX INC. – BREX ReIMbursement” dated 30 Jun 2025.\n3. Click the transaction’s Split option to open the “Split Transaction” dialog.\n4. In the first split row (already populated with vendor CHIPOTLE 1102):\n   • Ensure the description reads “Chipotle”.\n   • Choose category “52820 – Working Meals”.\n   • Enter the amount $13.41.\n5. In the second split row:\n   • Set the vendor to “Clerky and Domino Rizzi”.\n   • Set the category to “52600 – Legal & Professional Fees”.\n   • Click the Amount cell and type 1541.72, then press Enter so it shows “$1,541.72”.\n6. Click the vendor drop-down in the third split row to prepare for adding another vendor allocation, but do not fill it in yet.\n7. Switch back to the Brex “Expenses” tab to review the remaining reimbursement entries that still need to be split later.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 3},
#  {'attempt_id': 'uGxndQ1RnbGs',
#   'eval_task_id': 'uGxndQ1RnbGs',
#   'actions': "click(start_box='(1015,0)')",
#   'thinking': 'The Split Transaction dialog is open in Inkle, and the third row’s Vendor drop-down is expanded, waiting for the next selection. To decide which vendor comes next, I need to look at the original reimbursement list. The Brex tab titled “Expenses | Brex” sits near the upper-right area of the tab bar, just left of the current Inkle tab. I’ll click that tab now to bring the Brex expenses table back into view so I can read the remaining line items before continuing the split.',
#   'instruction': 'In Google Chrome, do the following bookkeeping task:\n1. Open the Brex dashboard and keep the “Expenses” table visible so you can reference individual reimbursement lines.\n2. In a separate browser tab, open the Inkle Books “Transactions” page and locate the transaction titled “BREX INC. – BREX ReIMbursement” dated 30 Jun 2025.\n3. Click the transaction’s Split option to open the “Split Transaction” dialog.\n4. In the first split row (already populated with vendor CHIPOTLE 1102):\n   • Ensure the description reads “Chipotle”.\n   • Choose category “52820 – Working Meals”.\n   • Enter the amount $13.41.\n5. In the second split row:\n   • Set the vendor to “Clerky and Domino Rizzi”.\n   • Set the category to “52600 – Legal & Professional Fees”.\n   • Click the Amount cell and type 1541.72, then press Enter so it shows “$1,541.72”.\n6. Click the vendor drop-down in the third split row to prepare for adding another vendor allocation, but do not fill it in yet.\n7. Switch back to the Brex “Expenses” tab to review the remaining reimbursement entries that still need to be split later.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 4},
#  {'attempt_id': 'jJc6IZnLTzEI',
#   'eval_task_id': 'jJc6IZnLTzEI',
#   'actions': "click(start_box='(287,1141)')",
#   'thinking': 'Chrome is still front-and-center on LinkedIn, yet my next steps belong in Apple Mail. The blue envelope icon in the Dock near the bottom left launches Mail, so bringing that app forward is the obvious first move. I’ll click the Mail icon now to switch applications and get to the search box.',
#   'instruction': 'Open the Apple Mail app, click in the search field, type “sfo to toronto” and press Return. From the search results, select the Air Canada booking-confirmation message and scroll through the email so the flight details are visible.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-08_160952_VX5RU',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': 'jJc6IZnLTzEI',
#   'eval_task_id': 'jJc6IZnLTzEI',
#   'actions': "click(start_box='(1725,76)')",
#   'thinking': 'Mail is front-and-center now, showing my message list on the left and an empty reading pane. The search box in the top-right corner is blank, so to start my query I need the cursor there. I’ll click inside that search field in the top right so it becomes active and ready for me to type “sfo to toronto.”',
#   'instruction': 'Open the Apple Mail app, click in the search field, type “sfo to toronto” and press Return. From the search results, select the Air Canada booking-confirmation message and scroll through the email so the flight details are visible.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-08_160952_VX5RU',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 1},
#  {'attempt_id': 'jJc6IZnLTzEI',
#   'eval_task_id': 'jJc6IZnLTzEI',
#   'actions': "click(start_box='(338,247)')",
#   'thinking': 'Mail now shows six matches in the left-hand results list, with a pink-highlighted “Air Canada — 2025 Toronto - San Francisco…” entry at the very top. The reading pane is empty and says “No Message Selected,” so the flight details I need aren’t visible yet. The quickest way to expose them is to open that top hit. I’ll click the first result in the list to load the full booking-confirmation email in the reading pane.',
#   'instruction': 'Open the Apple Mail app, click in the search field, type “sfo to toronto” and press Return. From the search results, select the Air Canada booking-confirmation message and scroll through the email so the flight details are visible.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-08_160952_VX5RU',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 3},
#  {'attempt_id': 'UhkEu5Fhwz6M',
#   'eval_task_id': 'UhkEu5Fhwz6M',
#   'actions': "click(start_box='(382,161)')",
#   'thinking': 'Google Calendar is open in 4-day view, and the header shows “August 2025.” To the left of the month label, the navigation arrows sit beside the Today button. I’m not totally sure this is the first 4-day block I need, so I’ll click the left-pointing arrow (“Previous period”) in the top bar to shift the calendar back one set of four days. Once I see where that lands, I can move forward or stop on the correct range.',
#   'instruction': 'Open Google Calendar and switch to the 4-day view if it isn’t already active. Use the left- and right-arrow buttons beside the Today button to navigate until the 4-day range that includes Thursday, 21 August 2025 (Thu 21 Aug – Sun 24 Aug) is visible. On Thursday, 21 August, click the empty time slot from 11:00 AM to 12:00 PM to bring up the quick-add event dialog. In the Title field, type “Sean NY”. Leave the default date (Thu 21 Aug 2025) and time (11:00 AM – 12:00 PM) as they are, then click the blue Save button to add the new event to the calendar.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-08_160952_VX5RU',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': 'UhkEu5Fhwz6M',
#   'eval_task_id': 'UhkEu5Fhwz6M',
#   'actions': "click(start_box='(416,175)')",
#   'thinking': 'The 4-day grid now spans Sun 17 Aug to Wed 20 Aug, so Thursday the 21st is still missing. The small right-pointing arrow just right of the Today button in the header moves the view forward by one block of four days. I’ll click that arrow to reach the range that starts with Thu 21 Aug.',
#   'instruction': 'Open Google Calendar and switch to the 4-day view if it isn’t already active. Use the left- and right-arrow buttons beside the Today button to navigate until the 4-day range that includes Thursday, 21 August 2025 (Thu 21 Aug – Sun 24 Aug) is visible. On Thursday, 21 August, click the empty time slot from 11:00 AM to 12:00 PM to bring up the quick-add event dialog. In the Title field, type “Sean NY”. Leave the default date (Thu 21 Aug 2025) and time (11:00 AM – 12:00 PM) as they are, then click the blue Save button to add the new event to the calendar.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-08_160952_VX5RU',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 1},
#  {'attempt_id': 'UhkEu5Fhwz6M',
#   'eval_task_id': 'UhkEu5Fhwz6M',
#   'actions': "click(start_box='(477,495)')",
#   'thinking': 'The 4-day grid now runs from Thu 21 Aug through Sun 24 Aug, so the correct range is on screen. In the first column for Thursday, the 11:00 AM row is empty and ready for an event. To bring up the quick-add dialog where I can enter the title, I’ll click this blank 11:00 AM–12:00 PM slot.',
#   'instruction': 'Open Google Calendar and switch to the 4-day view if it isn’t already active. Use the left- and right-arrow buttons beside the Today button to navigate until the 4-day range that includes Thursday, 21 August 2025 (Thu 21 Aug – Sun 24 Aug) is visible. On Thursday, 21 August, click the empty time slot from 11:00 AM to 12:00 PM to bring up the quick-add event dialog. In the Title field, type “Sean NY”. Leave the default date (Thu 21 Aug 2025) and time (11:00 AM – 12:00 PM) as they are, then click the blue Save button to add the new event to the calendar.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-08_160952_VX5RU',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 2},
#  {'attempt_id': 'UhkEu5Fhwz6M',
#   'eval_task_id': 'UhkEu5Fhwz6M',
#   'actions': "click(start_box='(800,580)')",
#   'thinking': 'The quick-add dialog is still centered on the screen, now showing the title field filled with “Sean NY” and the time row reading Thursday, August 21, 11:00 am – 12:00 pm. All required details match the task, so the only thing left is to confirm the entry. The blue Save button sits at the bottom right of this pop-up—clicking it will write the event to the calendar grid. I’ll hit that button to finalize the new meeting slot.',
#   'instruction': 'Open Google Calendar and switch to the 4-day view if it isn’t already active. Use the left- and right-arrow buttons beside the Today button to navigate until the 4-day range that includes Thursday, 21 August 2025 (Thu 21 Aug – Sun 24 Aug) is visible. On Thursday, 21 August, click the empty time slot from 11:00 AM to 12:00 PM to bring up the quick-add event dialog. In the Title field, type “Sean NY”. Leave the default date (Thu 21 Aug 2025) and time (11:00 AM – 12:00 PM) as they are, then click the blue Save button to add the new event to the calendar.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-08_160952_VX5RU',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 4},
#  {'attempt_id': '7W7x3yyEiPG4',
#   'eval_task_id': '7W7x3yyEiPG4',
#   'actions': "click(start_box='(787,284)')",
#   'thinking': 'The page is showing lots of ice-tray listings, and the search box at the top center already says “silicone ice tray.” To narrow this to trays that include lids, I need to edit that text. I’ll click inside the search field so the cursor appears and I can type my next phrase.',
#   'instruction': 'Go to Temu.com and locate the search bar. First, run a search for “silicone ice tray.” In the same search field, add the phrase “with lid” to narrow the results to trays that include lids and press Enter to refresh the list. Finally, refine the search once more by entering “multi set silicone ice tray with lid” and run the search so only multi-pack silicone ice-tray sets that include lids are displayed.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/Jarry/2025-07-07_002920_0SPCN',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': '7W7x3yyEiPG4',
#   'eval_task_id': '7W7x3yyEiPG4',
#   'actions': "click(start_box='(625,294)')",
#   'thinking': 'The page has refreshed and now shows trays that match “silicone ice tray with lid.” To refine the query to multi-packs, I first need the cursor active inside the same search box at the top center. I’ll click inside that field so I can prepend the words “multi set ” before running the next search.',
#   'instruction': 'Go to Temu.com and locate the search bar. First, run a search for “silicone ice tray.” In the same search field, add the phrase “with lid” to narrow the results to trays that include lids and press Enter to refresh the list. Finally, refine the search once more by entering “multi set silicone ice tray with lid” and run the search so only multi-pack silicone ice-tray sets that include lids are displayed.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/Jarry/2025-07-07_002920_0SPCN',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 2},
#  {'attempt_id': 'PnbpEWWA0HP4',
#   'eval_task_id': 'PnbpEWWA0HP4',
#   'actions': "click(start_box='(578,883)')",
#   'thinking': 'I’ve scrolled to the end of the database—the bottom row shows “Oven mitts,” and right beneath it there’s a blank row with an empty Name cell on the left side of the table. That’s the spot where the new item needs to go. I’ll click that empty Name cell so the cursor appears there, ready for me to type “Bowls” and then hit Tab to move to the next column.',
#   'instruction': 'Open the Notion workspace “Toronto Apartment Things,” navigate to the “Apartment Shopping List” database, scroll to the bottom of the table, click the empty row just under “Oven mitts,” type “Bowls” in the Name column, and press Tab to confirm the entry and move to the next column.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/Jarry/2025-07-07_002920_0SPCN',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 3},
#  {'attempt_id': 'oStlAe2i1yag',
#   'eval_task_id': 'oStlAe2i1yag',
#   'actions': "click(start_box='(1707,17)')",
#   'thinking': 'The active tab is a ChatGPT share page; I don’t want to overwrite it because I’ll need to refer back to these notes. The task says to start in a fresh tab, and I see the small + button at the far right of the tab strip—this is the quickest way to open a blank page without closing anything. I’ll click that + icon now to create a new tab where I can run the Google search.',
#   'instruction': 'Research the CoreWeave startup/accelerator program:\n1. Open a new browser tab.\n2. In the address bar, type “coreweave startup program” and press Enter.\n3. From the Google results, open the official CoreWeave blog post titled something like “Accelerator Program” (URL should be on coreweave.com).\n4. Scroll through the article to read the details about what the program offers (e.g., GPU cloud credits, discounts, eligibility, benefits).',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': 'oStlAe2i1yag',
#   'eval_task_id': 'oStlAe2i1yag',
#   'actions': "click(start_box='(319,511)')",
#   'thinking': 'The Google results page is up. Near the middle I see a blue link titled “Accelerator Program,” and the URL is blog.coreweave.com—this is the exact blog post I’m supposed to read. The top link is just the main CoreWeave site, so it won’t give the program details. I’ll click the “Accelerator Program” link in the center of the screen to load the article and review the startup benefits.',
#   'instruction': 'Research the CoreWeave startup/accelerator program:\n1. Open a new browser tab.\n2. In the address bar, type “coreweave startup program” and press Enter.\n3. From the Google results, open the official CoreWeave blog post titled something like “Accelerator Program” (URL should be on coreweave.com).\n4. Scroll through the article to read the details about what the program offers (e.g., GPU cloud credits, discounts, eligibility, benefits).',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 2},
#  {'attempt_id': 'nO6H5Tzi0e0T',
#   'eval_task_id': 'nO6H5Tzi0e0T',
#   'actions': "click(start_box='(70,577)')",
#   'thinking': 'The dashboard is open to Duo Copilot and the middle panel reads “No pending actions,” so I’m not yet in the task manager. In the left sidebar, under Engage, the Tasks item shows a blue “77” badge—exactly the section I need. I’ll click the Tasks row in the sidebar to load the list of those 77 pending tasks.',
#   'instruction': 'On the Amplemarket dashboard:\n1. In the left-hand sidebar, click Engage → Tasks (showing 77 pending items) to open the task manager.\n2. Once the Tasks page loads, place the cursor in the Search field of the filter panel and type the keyword “click” to filter tasks that match that term.\n3. After the filtered results appear, move to the Prospect section of the sidebar and click Lists to view your lead lists.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-08_160952_VX5RU',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': 'nO6H5Tzi0e0T',
#   'eval_task_id': 'nO6H5Tzi0e0T',
#   'actions': "click(start_box='(51,554)')",
#   'thinking': 'The main panel still shows Duo Copilot with “No pending actions,” so the task list hasn’t opened yet. The “Tasks” entry in the left sidebar, just below Calls, still shows the blue 77 badge and isn’t selected. I need that page to apply the search filter, so I’ll click the Tasks row in the sidebar again to force the Tasks view to load.',
#   'instruction': 'On the Amplemarket dashboard:\n1. In the left-hand sidebar, click Engage → Tasks (showing 77 pending items) to open the task manager.\n2. Once the Tasks page loads, place the cursor in the Search field of the filter panel and type the keyword “click” to filter tasks that match that term.\n3. After the filtered results appear, move to the Prospect section of the sidebar and click Lists to view your lead lists.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-08_160952_VX5RU',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 1},
#  {'attempt_id': 'nO6H5Tzi0e0T',
#   'eval_task_id': 'nO6H5Tzi0e0T',
#   'actions': "click(start_box='(410,470)')",
#   'thinking': 'The sidebar now highlights Tasks, but the main panel is still a blank white canvas with the blue loading dot—so the page is still initializing. I want the browser focus on this workspace so that, the moment the fields appear, I can jump straight into the filter panel and start typing. I’ll click once in the open area in the middle of the screen to bring focus to the Tasks page while it finishes loading.',
#   'instruction': 'On the Amplemarket dashboard:\n1. In the left-hand sidebar, click Engage → Tasks (showing 77 pending items) to open the task manager.\n2. Once the Tasks page loads, place the cursor in the Search field of the filter panel and type the keyword “click” to filter tasks that match that term.\n3. After the filtered results appear, move to the Prospect section of the sidebar and click Lists to view your lead lists.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-08_160952_VX5RU',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 2},
#  {'attempt_id': 'nO6H5Tzi0e0T',
#   'eval_task_id': 'nO6H5Tzi0e0T',
#   'actions': "click(start_box='(132,436)')",
#   'thinking': 'The Tasks page is filtered—the search box in the filter panel shows “click,” and the table on the right still lists the 77 tasks. I’ve completed the keyword search step, so the next part of the workflow is to review my lead lists. In the left sidebar, under the Prospect section, the row labeled “Lists” sits just above the Engage heading. Selecting it will leave the Task manager and bring up the Leads Lists view I need. I’ll click the “Lists” row in the sidebar now.',
#   'instruction': 'On the Amplemarket dashboard:\n1. In the left-hand sidebar, click Engage → Tasks (showing 77 pending items) to open the task manager.\n2. Once the Tasks page loads, place the cursor in the Search field of the filter panel and type the keyword “click” to filter tasks that match that term.\n3. After the filtered results appear, move to the Prospect section of the sidebar and click Lists to view your lead lists.',
#   'trajectory_length': 6,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/aryan_91532/2025-07-08_160952_VX5RU',
#   'image_turns_start': 0,
#   'image_turns_end': 5,
#   'text_turns_start': 0,
#   'text_turns_end': 5,
#   'unmask_last_only': False,
#   'action_index': 4},
#  {'attempt_id': 'UNbdWSqaPWBC',
#   'eval_task_id': 'UNbdWSqaPWBC',
#   'actions': "click(start_box='(574,64)')",
# ...
#   'trajectory_length': 11,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 10,
#   'text_turns_start': 0,
#   'text_turns_end': 10,
#   'unmask_last_only': False,
#   'action_index': 7},
#  {'attempt_id': 'dHcBCq2rQoEl',
#   'eval_task_id': 'dHcBCq2rQoEl',
#   'actions': "left_double(start_box='(679,362)')",
#   'thinking': 'The Deals page is still filtered for “AWS”—I can see the query in the text field near the top center and a list of AWS-related deals below it. I now need to check Oracle next, so the quickest way is to overwrite the existing text. I’ll double-click inside the search field to select the word “AWS,” which will let me immediately start typing the new provider name without having to backspace multiple times.',
#   'instruction': 'Research current cloud GPU offerings and discounts by cross-referencing YC Bookface deals with an existing ChatGPT pricing summary.  \n\nSteps:\n1. In a browser, open bookface.ycombinator.com/deals.\n2. Use the search box to look up the following providers one by one and note any credit amounts, usage limits, or special discounts:\n   • AWS  \n   • Oracle (OCI)  \n   • GCP  \n   • CoreWeave\n3. In a separate tab, open the shared ChatGPT conversation at https://chat.openai.com/share/6866c238-6410-8006-862f-73ec4b0c3a3 (it contains the article titled “Pricing per H100 GPU-Hour (On-Demand)”).\n4. Scroll through the ChatGPT article until you reach the section that lists on-demand H100 GPU-hour prices for each provider and the overall summary.\n5. Switch back and forth between the Bookface tab and the ChatGPT tab as needed to compare YC deal credits with the per-GPU-hour pricing.\n6. Compile a brief comparison highlighting which provider offers the best effective cost after applying YC credits or other discounts.',
#   'trajectory_length': 11,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 10,
#   'text_turns_start': 0,
#   'text_turns_end': 10,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': 'dHcBCq2rQoEl',
#   'eval_task_id': 'dHcBCq2rQoEl',
#   'actions': "click(start_box='(1493,0)')",
#   'thinking': 'The YC Deals page is now filtered to “GCP”—I see “GCP” in the text box at the top center and six matching deals listed below. I’ve captured what credits are offered here, so the next thing I need is the per-GPU-hour pricing from the ChatGPT article. That lives in the other tab with the ChatGPT icon near the far right of the tab bar. I’ll click that tab to switch over and review the pricing summary.',
#   'instruction': 'Research current cloud GPU offerings and discounts by cross-referencing YC Bookface deals with an existing ChatGPT pricing summary.  \n\nSteps:\n1. In a browser, open bookface.ycombinator.com/deals.\n2. Use the search box to look up the following providers one by one and note any credit amounts, usage limits, or special discounts:\n   • AWS  \n   • Oracle (OCI)  \n   • GCP  \n   • CoreWeave\n3. In a separate tab, open the shared ChatGPT conversation at https://chat.openai.com/share/6866c238-6410-8006-862f-73ec4b0c3a3 (it contains the article titled “Pricing per H100 GPU-Hour (On-Demand)”).\n4. Scroll through the ChatGPT article until you reach the section that lists on-demand H100 GPU-hour prices for each provider and the overall summary.\n5. Switch back and forth between the Bookface tab and the ChatGPT tab as needed to compare YC deal credits with the per-GPU-hour pricing.\n6. Compile a brief comparison highlighting which provider offers the best effective cost after applying YC credits or other discounts.',
#   'trajectory_length': 11,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 10,
#   'text_turns_start': 0,
#   'text_turns_end': 10,
#   'unmask_last_only': False,
#   'action_index': 3},
#  {'attempt_id': 'dHcBCq2rQoEl',
#   'eval_task_id': 'dHcBCq2rQoEl',
#   'actions': "click(start_box='(522,0)')",
#   'thinking': 'The ChatGPT page is open and I can see the bullet that says “CoreWeave … $6.16 per GPU-hour,” so I’ve got the price point. To compare it with any YC credits, I need to get back to the Bookface Deals page. The tab with the orange Y logo and the title starting “Bookf…” sits a few positions to the left in the top tab bar. I’ll click that tab to bring the YC search page into view so I can look up CoreWeave’s deal.',
#   'instruction': 'Research current cloud GPU offerings and discounts by cross-referencing YC Bookface deals with an existing ChatGPT pricing summary.  \n\nSteps:\n1. In a browser, open bookface.ycombinator.com/deals.\n2. Use the search box to look up the following providers one by one and note any credit amounts, usage limits, or special discounts:\n   • AWS  \n   • Oracle (OCI)  \n   • GCP  \n   • CoreWeave\n3. In a separate tab, open the shared ChatGPT conversation at https://chat.openai.com/share/6866c238-6410-8006-862f-73ec4b0c3a3 (it contains the article titled “Pricing per H100 GPU-Hour (On-Demand)”).\n4. Scroll through the ChatGPT article until you reach the section that lists on-demand H100 GPU-hour prices for each provider and the overall summary.\n5. Switch back and forth between the Bookface tab and the ChatGPT tab as needed to compare YC deal credits with the per-GPU-hour pricing.\n6. Compile a brief comparison highlighting which provider offers the best effective cost after applying YC credits or other discounts.',
#   'trajectory_length': 11,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 10,
#   'text_turns_start': 0,
#   'text_turns_end': 10,
#   'unmask_last_only': False,
#   'action_index': 5},
#  {'attempt_id': 'dHcBCq2rQoEl',
#   'eval_task_id': 'dHcBCq2rQoEl',
#   'actions': "click(start_box='(1507,0)')",
#   'thinking': 'The YC Deals page is up; the address bar already reads ?query=coreweave, yet the list in the middle still shows generic entries like Supabase and PostHog, so it looks like CoreWeave doesn’t have a YC deal. Since I’ve gathered that there’s no credit to offset their $6.16 GPU-hour price, the next thing I need is to revisit the ChatGPT article for the final cost comparison. The ChatGPT share tab sits near the far right of the tab bar, so I’ll click that tab now to switch back to the pricing summary.',
#   'instruction': 'Research current cloud GPU offerings and discounts by cross-referencing YC Bookface deals with an existing ChatGPT pricing summary.  \n\nSteps:\n1. In a browser, open bookface.ycombinator.com/deals.\n2. Use the search box to look up the following providers one by one and note any credit amounts, usage limits, or special discounts:\n   • AWS  \n   • Oracle (OCI)  \n   • GCP  \n   • CoreWeave\n3. In a separate tab, open the shared ChatGPT conversation at https://chat.openai.com/share/6866c238-6410-8006-862f-73ec4b0c3a3 (it contains the article titled “Pricing per H100 GPU-Hour (On-Demand)”).\n4. Scroll through the ChatGPT article until you reach the section that lists on-demand H100 GPU-hour prices for each provider and the overall summary.\n5. Switch back and forth between the Bookface tab and the ChatGPT tab as needed to compare YC deal credits with the per-GPU-hour pricing.\n6. Compile a brief comparison highlighting which provider offers the best effective cost after applying YC credits or other discounts.',
#   'trajectory_length': 11,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-04_110139_B6VYF',
#   'image_turns_start': 0,
#   'image_turns_end': 10,
#   'text_turns_start': 0,
#   'text_turns_end': 10,
#   'unmask_last_only': False,
#   'action_index': 7},
#  {'attempt_id': 'D230SnrBECIy',
#   'eval_task_id': 'D230SnrBECIy',
#   'actions': "click(start_box='(1241,828)')",
#   'thinking': "The Stamp House split line still shows an empty memo box—the white text field just right of the Category column on that line—so this tag hasn't been copied over yet. To add the same “#anniversary2025” note, I first need the cursor inside that field. I’ll click the empty memo box now to put it in edit mode, then I can paste the text.",
#   'instruction': 'In the YNAB web app (Joyce’s Budget), open the TD Chequing account and edit the 27-Jul-2025 transaction from “Stamp House” ($1,415.41) as a split.\n1. Verify the existing split lines, then add or adjust them so they read:\n   • Payee: 736 Spadina – Category: Bills › Rent – Outflow $1,300.00\n   • Payee: (blank) – Category: Wants › Stratford trip – Inflow $49.65 – Memo “#anniversary2025; various foods/shopping in Stratford”\n   • Payee: Uber Eats – Category: Wants › Dining out – Outflow $20.97\n   • Payee: Shoppers Drug Mart – Category: Needs › Home consumables – Outflow $15.50\n   • Payee: Stamp House – Category: Wants › Stratford trip – Outflow $159.59 – Memo “#anniversary2025; various foods/shopping in Stratford”\n2. Click “Add another split” to create an additional blank line for a future entry.\n3. Press “Save” to close the split editor.\n4. After saving, click the highlighted “This needs a category” warning on the new blank split line to open the category chooser so it can be assigned later.',
#   'trajectory_length': 11,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-27_193551_TX1BD',
#   'image_turns_start': 0,
#   'image_turns_end': 10,
#   'text_turns_start': 0,
#   'text_turns_end': 10,
#   'unmask_last_only': False,
#   'action_index': 0},
#  {'attempt_id': 'D230SnrBECIy',
#   'eval_task_id': 'D230SnrBECIy',
#   'actions': "click(start_box='(1241,828)')",
#   'thinking': 'The Stamp House split line still shows the grey “memo” placeholder and there’s no cursor, so my Enter press didn’t actually activate the field. I need that cell in edit mode before I paste the tag. I’ll click the empty memo box again to put focus there and get the cursor blinking.',
#   'instruction': 'In the YNAB web app (Joyce’s Budget), open the TD Chequing account and edit the 27-Jul-2025 transaction from “Stamp House” ($1,415.41) as a split.\n1. Verify the existing split lines, then add or adjust them so they read:\n   • Payee: 736 Spadina – Category: Bills › Rent – Outflow $1,300.00\n   • Payee: (blank) – Category: Wants › Stratford trip – Inflow $49.65 – Memo “#anniversary2025; various foods/shopping in Stratford”\n   • Payee: Uber Eats – Category: Wants › Dining out – Outflow $20.97\n   • Payee: Shoppers Drug Mart – Category: Needs › Home consumables – Outflow $15.50\n   • Payee: Stamp House – Category: Wants › Stratford trip – Outflow $159.59 – Memo “#anniversary2025; various foods/shopping in Stratford”\n2. Click “Add another split” to create an additional blank line for a future entry.\n3. Press “Save” to close the split editor.\n4. After saving, click the highlighted “This needs a category” warning on the new blank split line to open the category chooser so it can be assigned later.',
#   'trajectory_length': 11,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-27_193551_TX1BD',
#   'image_turns_start': 0,
#   'image_turns_end': 10,
#   'text_turns_start': 0,
#   'text_turns_end': 10,
#   'unmask_last_only': False,
#   'action_index': 2},
#  {'attempt_id': 'D230SnrBECIy',
#   'eval_task_id': 'D230SnrBECIy',
#   'actions': "click(start_box='(1326,696)')",
#   'thinking': 'The split editor is open and I can see the inflow line—blank payee, Wants › Stratford trip—still shows only “#anniversary2025” in the memo column, but the instructions call for the longer note. I need the cursor inside that memo field so I can add the rest of the text. I’ll click the memo cell in the middle of the grid to activate it for editing.',
#   'instruction': 'In the YNAB web app (Joyce’s Budget), open the TD Chequing account and edit the 27-Jul-2025 transaction from “Stamp House” ($1,415.41) as a split.\n1. Verify the existing split lines, then add or adjust them so they read:\n   • Payee: 736 Spadina – Category: Bills › Rent – Outflow $1,300.00\n   • Payee: (blank) – Category: Wants › Stratford trip – Inflow $49.65 – Memo “#anniversary2025; various foods/shopping in Stratford”\n   • Payee: Uber Eats – Category: Wants › Dining out – Outflow $20.97\n   • Payee: Shoppers Drug Mart – Category: Needs › Home consumables – Outflow $15.50\n   • Payee: Stamp House – Category: Wants › Stratford trip – Outflow $159.59 – Memo “#anniversary2025; various foods/shopping in Stratford”\n2. Click “Add another split” to create an additional blank line for a future entry.\n3. Press “Save” to close the split editor.\n4. After saving, click the highlighted “This needs a category” warning on the new blank split line to open the category chooser so it can be assigned later.',
#   'trajectory_length': 11,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-27_193551_TX1BD',
#   'image_turns_start': 0,
#   'image_turns_end': 10,
#   'text_turns_start': 0,
#   'text_turns_end': 10,
#   'unmask_last_only': False,
#   'action_index': 4},
#  {'attempt_id': 'D230SnrBECIy',
#   'eval_task_id': 'D230SnrBECIy',
#   'actions': "click(start_box='(1326,696)')",
#   'thinking': 'The split table is still open. The inflow line—blank payee, Wants › Stratford trip—shows only “#anniversary2025” in its memo cell, and I don’t see a blinking cursor, so the field isn’t active yet. I need to append the extra note, so I’ll click once more inside that memo box in the middle-right of the grid to put it into edit mode and get the cursor ready for typing the rest of the memo.',
#   'instruction': 'In the YNAB web app (Joyce’s Budget), open the TD Chequing account and edit the 27-Jul-2025 transaction from “Stamp House” ($1,415.41) as a split.\n1. Verify the existing split lines, then add or adjust them so they read:\n   • Payee: 736 Spadina – Category: Bills › Rent – Outflow $1,300.00\n   • Payee: (blank) – Category: Wants › Stratford trip – Inflow $49.65 – Memo “#anniversary2025; various foods/shopping in Stratford”\n   • Payee: Uber Eats – Category: Wants › Dining out – Outflow $20.97\n   • Payee: Shoppers Drug Mart – Category: Needs › Home consumables – Outflow $15.50\n   • Payee: Stamp House – Category: Wants › Stratford trip – Outflow $159.59 – Memo “#anniversary2025; various foods/shopping in Stratford”\n2. Click “Add another split” to create an additional blank line for a future entry.\n3. Press “Save” to close the split editor.\n4. After saving, click the highlighted “This needs a category” warning on the new blank split line to open the category chooser so it can be assigned later.',
#   'trajectory_length': 11,
#   'source_dir': 'gs://induction-labs-data-ext/action_capture/joyceliu/2025-07-27_193551_TX1BD',
#   'image_turns_start': 0,
#   'image_turns_end': 10,
#   'text_turns_start': 0,
#   'text_turns_end': 10,
#   'unmask_last_only': False,
#   'action_index': 5},
#  ...]

# %%
import pandas as pd

df = pd.read_json("gs://induction-labs/passive_data/smooth_brain_clicks/2025-08-15/reprocess_all_no_loading-01-36-47/samples.jsonl", lines=True)

df

df['text_turns_end'] = df['image_turns_end'] = 1
# Out:
#           attempt_id    eval_task_id                           actions  \
# 0     WM1VRv1ZGWA0-2  WM1VRv1ZGWA0-2     [click(start_box='(1702,5)')]
# 1     4NhwPtQL8ePo-0  4NhwPtQL8ePo-0    [click(start_box='(657,629)')]
# 2     4NhwPtQL8ePo-3  4NhwPtQL8ePo-3    [click(start_box='(715,626)')]
# 3     ysBGeJaIcIg0-1  ysBGeJaIcIg0-1    [click(start_box='(722,672)')]
# 4     WM1VRv1ZGWA0-0  WM1VRv1ZGWA0-0   [click(start_box='(1559,227)')]
# ...              ...             ...                               ...
# 2618  HahLlXsiEkeV-6  HahLlXsiEkeV-6    [click(start_box='(945,837)')]
# 2619  ixVnKchUDibi-3  ixVnKchUDibi-3    [click(start_box='(588,465)')]
# 2620  HahLlXsiEkeV-8  HahLlXsiEkeV-8  [click(start_box='(1143,1054)')]
# 2621  6jVs1SHFLU1B-1  6jVs1SHFLU1B-1    [click(start_box='(404,300)')]
# 2622  T79rECGDLoxJ-3  T79rECGDLoxJ-3      [click(start_box='(485,0)')]
#
#                                                thinking  \
# 0     [My goal is to open a new blank tab. I see the...
# 1     [My goal is to place the text cursor in the bu...
# 2     [My goal is to place the cursor exactly at the...
# 3     [My goal is to reveal the sub-items under "Cor...
# 4     [My goal is to view the redemption instruction...
# ...                                                 ...
# 2618  [My goal is to confirm the font settings and c...
# 2619  [My goal is to position the caret where the gu...
# 2620  [My goal is to begin recording the annotation....
# 2621  [My goal is to change the document’s font. I s...
# 2622  [My goal is to view the YC Bookface discount d...
#
#                                             instruction  trajectory_length  \
# 0                   Click the + icon to open a new tab.                  1
# 1     Click inside the bullet ending with "(no hyper...                  1
# 2     Click at the end of the bullet that ends with ...                  1
# 3                        Expand the "Coreweave" toggle.                  1
# 4      Click the “Show redemption instructions” button.                  1
# ...                                                 ...                ...
# 2618   Click the OK button to close the Options window.                  1
# 2619  Click the empty line just below the </button> ...                  1
# 2620  Click the blue “Start Annotation” button at th...                  1
# 2621                        Click in the font-name box.                  1
# 2622             Switch to the YC Bookface browser tab.                  1
#
#                                              source_dir  image_turns_start  \
# 0     gs://induction-labs/passive_data/2025-08-14/re...                  0
# 1     gs://induction-labs/passive_data/2025-08-14/re...                  0
# 2     gs://induction-labs/passive_data/2025-08-14/re...                  0
# 3     gs://induction-labs/passive_data/2025-08-14/re...                  0
# 4     gs://induction-labs/passive_data/2025-08-14/re...                  0
# ...                                                 ...                ...
# 2618  gs://induction-labs/passive_data/2025-08-14/re...                  0
# 2619  gs://induction-labs/passive_data/2025-08-14/re...                  0
# 2620  gs://induction-labs/passive_data/2025-08-14/re...                  0
# 2621  gs://induction-labs/passive_data/2025-08-14/re...                  0
# 2622  gs://induction-labs/passive_data/2025-08-14/re...                  0
#
#       image_turns_end  text_turns_start  text_turns_end  unmask_last_only
# 0                   0                 0               0             False
# 1                   0                 0               0             False
# 2                   0                 0               0             False
# 3                   0                 0               0             False
# 4                   0                 0               0             False
# ...               ...               ...             ...               ...
# 2618                0                 0               0             False
# 2619                0                 0               0             False
# 2620                0                 0               0             False
# 2621                0                 0               0             False
# 2622                0                 0               0             False
#
# [2623 rows x 12 columns]

# %%
df['text_turns_end'] = df['image_turns_end'] = 1
df
# Out:
#           attempt_id    eval_task_id                           actions  \
# 0     WM1VRv1ZGWA0-2  WM1VRv1ZGWA0-2     [click(start_box='(1702,5)')]
# 1     4NhwPtQL8ePo-0  4NhwPtQL8ePo-0    [click(start_box='(657,629)')]
# 2     4NhwPtQL8ePo-3  4NhwPtQL8ePo-3    [click(start_box='(715,626)')]
# 3     ysBGeJaIcIg0-1  ysBGeJaIcIg0-1    [click(start_box='(722,672)')]
# 4     WM1VRv1ZGWA0-0  WM1VRv1ZGWA0-0   [click(start_box='(1559,227)')]
# ...              ...             ...                               ...
# 2618  HahLlXsiEkeV-6  HahLlXsiEkeV-6    [click(start_box='(945,837)')]
# 2619  ixVnKchUDibi-3  ixVnKchUDibi-3    [click(start_box='(588,465)')]
# 2620  HahLlXsiEkeV-8  HahLlXsiEkeV-8  [click(start_box='(1143,1054)')]
# 2621  6jVs1SHFLU1B-1  6jVs1SHFLU1B-1    [click(start_box='(404,300)')]
# 2622  T79rECGDLoxJ-3  T79rECGDLoxJ-3      [click(start_box='(485,0)')]
#
#                                                thinking  \
# 0     [My goal is to open a new blank tab. I see the...
# 1     [My goal is to place the text cursor in the bu...
# 2     [My goal is to place the cursor exactly at the...
# 3     [My goal is to reveal the sub-items under "Cor...
# 4     [My goal is to view the redemption instruction...
# ...                                                 ...
# 2618  [My goal is to confirm the font settings and c...
# 2619  [My goal is to position the caret where the gu...
# 2620  [My goal is to begin recording the annotation....
# 2621  [My goal is to change the document’s font. I s...
# 2622  [My goal is to view the YC Bookface discount d...
#
#                                             instruction  trajectory_length  \
# 0                   Click the + icon to open a new tab.                  1
# 1     Click inside the bullet ending with "(no hyper...                  1
# 2     Click at the end of the bullet that ends with ...                  1
# 3                        Expand the "Coreweave" toggle.                  1
# 4      Click the “Show redemption instructions” button.                  1
# ...                                                 ...                ...
# 2618   Click the OK button to close the Options window.                  1
# 2619  Click the empty line just below the </button> ...                  1
# 2620  Click the blue “Start Annotation” button at th...                  1
# 2621                        Click in the font-name box.                  1
# 2622             Switch to the YC Bookface browser tab.                  1
#
#                                              source_dir  image_turns_start  \
# 0     gs://induction-labs/passive_data/2025-08-14/re...                  0
# 1     gs://induction-labs/passive_data/2025-08-14/re...                  0
# 2     gs://induction-labs/passive_data/2025-08-14/re...                  0
# 3     gs://induction-labs/passive_data/2025-08-14/re...                  0
# 4     gs://induction-labs/passive_data/2025-08-14/re...                  0
# ...                                                 ...                ...
# 2618  gs://induction-labs/passive_data/2025-08-14/re...                  0
# 2619  gs://induction-labs/passive_data/2025-08-14/re...                  0
# 2620  gs://induction-labs/passive_data/2025-08-14/re...                  0
# 2621  gs://induction-labs/passive_data/2025-08-14/re...                  0
# 2622  gs://induction-labs/passive_data/2025-08-14/re...                  0
#
#       image_turns_end  text_turns_start  text_turns_end  unmask_last_only
# 0                   1                 0               1             False
# 1                   1                 0               1             False
# 2                   1                 0               1             False
# 3                   1                 0               1             False
# 4                   1                 0               1             False
# ...               ...               ...             ...               ...
# 2618                1                 0               1             False
# 2619                1                 0               1             False
# 2620                1                 0               1             False
# 2621                1                 0               1             False
# 2622                1                 0               1             False
#
# [2623 rows x 12 columns]

# %%
df.to_json("gs://induction-labs/passive_data/smooth_brain_clicks/2025-08-15/reprocess_all_no_loading-01-36-47/samples.jsonl", orient='records', lines=True)
