# %%
import pandas as pd

# %%
df = pd.read_json("/home/ubuntu/.cache/huggingface/hub/datasets--OS-Copilot--ScreenSpot-v2/snapshots/5efbb1f1b5463a575f2eb7bc30fe29e49c15f93c/screenspot_desktop_v2.json")
df
# Out:
#                                     img_filename                   bbox  \
# 0    pc_ede36f9b-1154-4f76-b7f8-c15d7d3f9b6e.png      [910, 78, 44, 34]
# 1    pc_5e09e8e9-7ef6-44be-ad54-aeaeac151897.png       [835, 0, 36, 30]
# 2    pc_2c6dc6ea-fd6f-4cbb-9954-2d6a68610a48.png  [1477, 450, 184, 230]
# 3    pc_b072d03a-51cb-4dd6-bdeb-152d3fd44e6b.png    [176, 202, 99, 101]
# 4    pc_ac2d2c5e-fe5a-4233-95b4-2de18ef76a9e.png     [635, 360, 42, 63]
# ..                                           ...                    ...
# 329                                pc_uuhwlx.png  [1309, 526, 114, 132]
# 330                                pc_vcud9k.png   [269, 127, 113, 132]
# 331                                pc_z7ydq8.png  [1466, 644, 147, 136]
# 332                                pc_zuyj00.png   [1744, 281, 258, 53]
# 333                                pc_aaaaaa.png    [701, 321, 417, 34]
#
#                                 instruction data_type data_source
# 0                         close this window      icon     windows
# 1                      minimize this window      icon     windows
# 2           view solitaire daily challenges      text     windows
# 3                  open the Microsoft store      text     windows
# 4                          adjust the style      text     windows
# ..                                      ...       ...         ...
# 329                     open the calculator      text        shop
# 330                      insert a new slide      text        shop
# 331      view more information about bomber      text        shop
# 332  adjust the options of  "show previous"      icon        shop
# 333                      enter my full name      text        shop
#
# [334 rows x 5 columns]

# %%
df['x1'] = df['bbox'].apply(lambda x: x[0])
df['y1'] = df['bbox'].apply(lambda x: x[1]) 
df['x2'] = df['bbox'].apply(lambda x: x[2]) + df['x1']
df['y2'] = df['bbox'].apply(lambda x: x[3]) + df['y1']

# %%
df
# Out:
#                                     img_filename                   bbox  \
# 0    pc_ede36f9b-1154-4f76-b7f8-c15d7d3f9b6e.png      [910, 78, 44, 34]
# 1    pc_5e09e8e9-7ef6-44be-ad54-aeaeac151897.png       [835, 0, 36, 30]
# 2    pc_2c6dc6ea-fd6f-4cbb-9954-2d6a68610a48.png  [1477, 450, 184, 230]
# 3    pc_b072d03a-51cb-4dd6-bdeb-152d3fd44e6b.png    [176, 202, 99, 101]
# 4    pc_ac2d2c5e-fe5a-4233-95b4-2de18ef76a9e.png     [635, 360, 42, 63]
# ..                                           ...                    ...
# 329                                pc_uuhwlx.png  [1309, 526, 114, 132]
# 330                                pc_vcud9k.png   [269, 127, 113, 132]
# 331                                pc_z7ydq8.png  [1466, 644, 147, 136]
# 332                                pc_zuyj00.png   [1744, 281, 258, 53]
# 333                                pc_aaaaaa.png    [701, 321, 417, 34]
#
#                                 instruction data_type data_source    x1   y1  \
# 0                         close this window      icon     windows   910   78
# 1                      minimize this window      icon     windows   835    0
# 2           view solitaire daily challenges      text     windows  1477  450
# 3                  open the Microsoft store      text     windows   176  202
# 4                          adjust the style      text     windows   635  360
# ..                                      ...       ...         ...   ...  ...
# 329                     open the calculator      text        shop  1309  526
# 330                      insert a new slide      text        shop   269  127
# 331      view more information about bomber      text        shop  1466  644
# 332  adjust the options of  "show previous"      icon        shop  1744  281
# 333                      enter my full name      text        shop   701  321
#
#        x2   y2        id  width  height  \
# 0     954  112  7HlAEPbj    960     540
# 1     871   30  5M0ybPZC    960     540
# 2    1661  680  WHTQNchN   1920    1080
# 3     275  303  bnGg2tMZ    960     540
# 4     677  423  OkgCzIt8    960     540
# ..    ...  ...       ...    ...     ...
# 329  1423  658  8gyPfDlO   2560    1440
# 330   382  259  RFq5Y47L   2880    1800
# 331  1613  780  A6ctmJfK   2560    1440
# 332  2002  334  JqN5qpie   2880    1800
# 333  1118  355  f1KnETPP   2560    1440
#
#                                                  image
# 0    screenspotv2_image/pc_ede36f9b-1154-4f76-b7f8-...
# 1    screenspotv2_image/pc_5e09e8e9-7ef6-44be-ad54-...
# 2    screenspotv2_image/pc_2c6dc6ea-fd6f-4cbb-9954-...
# 3    screenspotv2_image/pc_b072d03a-51cb-4dd6-bdeb-...
# 4    screenspotv2_image/pc_ac2d2c5e-fe5a-4233-95b4-...
# ..                                                 ...
# 329                   screenspotv2_image/pc_uuhwlx.png
# 330                   screenspotv2_image/pc_vcud9k.png
# 331                   screenspotv2_image/pc_z7ydq8.png
# 332                   screenspotv2_image/pc_zuyj00.png
# 333                   screenspotv2_image/pc_aaaaaa.png
#
# [334 rows x 13 columns]

# %%
from modeling.utils.gen_id import gen_id
df['id'] = df.apply(lambda x: gen_id(8), axis=1)
df
# Out:
#                                     img_filename                   bbox  \
# 0    pc_ede36f9b-1154-4f76-b7f8-c15d7d3f9b6e.png      [910, 78, 44, 34]
# 1    pc_5e09e8e9-7ef6-44be-ad54-aeaeac151897.png       [835, 0, 36, 30]
# 2    pc_2c6dc6ea-fd6f-4cbb-9954-2d6a68610a48.png  [1477, 450, 184, 230]
# 3    pc_b072d03a-51cb-4dd6-bdeb-152d3fd44e6b.png    [176, 202, 99, 101]
# 4    pc_ac2d2c5e-fe5a-4233-95b4-2de18ef76a9e.png     [635, 360, 42, 63]
# ..                                           ...                    ...
# 329                                pc_uuhwlx.png  [1309, 526, 114, 132]
# 330                                pc_vcud9k.png   [269, 127, 113, 132]
# 331                                pc_z7ydq8.png  [1466, 644, 147, 136]
# 332                                pc_zuyj00.png   [1744, 281, 258, 53]
# 333                                pc_aaaaaa.png    [701, 321, 417, 34]
#
#                                 instruction data_type data_source    x1   y1  \
# 0                         close this window      icon     windows   910   78
# 1                      minimize this window      icon     windows   835    0
# 2           view solitaire daily challenges      text     windows  1477  450
# 3                  open the Microsoft store      text     windows   176  202
# 4                          adjust the style      text     windows   635  360
# ..                                      ...       ...         ...   ...  ...
# 329                     open the calculator      text        shop  1309  526
# 330                      insert a new slide      text        shop   269  127
# 331      view more information about bomber      text        shop  1466  644
# 332  adjust the options of  "show previous"      icon        shop  1744  281
# 333                      enter my full name      text        shop   701  321
#
#       x2   y2        id
# 0     44   34  7HlAEPbj
# 1     36   30  5M0ybPZC
# 2    184  230  WHTQNchN
# 3     99  101  bnGg2tMZ
# 4     42   63  OkgCzIt8
# ..   ...  ...       ...
# 329  114  132  8gyPfDlO
# 330  113  132  RFq5Y47L
# 331  147  136  A6ctmJfK
# 332  258   53  JqN5qpie
# 333  417   34  f1KnETPP
#
# [334 rows x 10 columns]

# %%
import pandas as pd
from PIL import Image
import os
base_path = "/home/ubuntu/.cache/huggingface/hub/datasets--OS-Copilot--ScreenSpot-v2/snapshots/5efbb1f1b5463a575f2eb7bc30fe29e49c15f93c/screenspotv2_image"

# Method 1: Using apply() - most pandas-like
def get_image_dimensions(img_path):
    img_path = os.path.join(base_path, img_path)
    try:
        with Image.open(img_path) as img:
            return pd.Series({'width': img.width, 'height': img.height})
    except Exception as e:
        print(f"Error loading {img_path}: {e}")
        return pd.Series({'width': None, 'height': None})

# Apply to DataFrame

# %%
df[['width', 'height']] = df['img_filename'].apply(get_image_dimensions)

# %%
df
# Out:
#                                     img_filename                   bbox  \
# 0    pc_ede36f9b-1154-4f76-b7f8-c15d7d3f9b6e.png      [910, 78, 44, 34]
# 1    pc_5e09e8e9-7ef6-44be-ad54-aeaeac151897.png       [835, 0, 36, 30]
# 2    pc_2c6dc6ea-fd6f-4cbb-9954-2d6a68610a48.png  [1477, 450, 184, 230]
# 3    pc_b072d03a-51cb-4dd6-bdeb-152d3fd44e6b.png    [176, 202, 99, 101]
# 4    pc_ac2d2c5e-fe5a-4233-95b4-2de18ef76a9e.png     [635, 360, 42, 63]
# ..                                           ...                    ...
# 329                                pc_uuhwlx.png  [1309, 526, 114, 132]
# 330                                pc_vcud9k.png   [269, 127, 113, 132]
# 331                                pc_z7ydq8.png  [1466, 644, 147, 136]
# 332                                pc_zuyj00.png   [1744, 281, 258, 53]
# 333                                pc_aaaaaa.png    [701, 321, 417, 34]
#
#                                 instruction data_type data_source    x1   y1  \
# 0                         close this window      icon     windows   910   78
# 1                      minimize this window      icon     windows   835    0
# 2           view solitaire daily challenges      text     windows  1477  450
# 3                  open the Microsoft store      text     windows   176  202
# 4                          adjust the style      text     windows   635  360
# ..                                      ...       ...         ...   ...  ...
# 329                     open the calculator      text        shop  1309  526
# 330                      insert a new slide      text        shop   269  127
# 331      view more information about bomber      text        shop  1466  644
# 332  adjust the options of  "show previous"      icon        shop  1744  281
# 333                      enter my full name      text        shop   701  321
#
#       x2   y2        id  width  height
# 0     44   34  7HlAEPbj    960     540
# 1     36   30  5M0ybPZC    960     540
# 2    184  230  WHTQNchN   1920    1080
# 3     99  101  bnGg2tMZ    960     540
# 4     42   63  OkgCzIt8    960     540
# ..   ...  ...       ...    ...     ...
# 329  114  132  8gyPfDlO   2560    1440
# 330  113  132  RFq5Y47L   2880    1800
# 331  147  136  A6ctmJfK   2560    1440
# 332  258   53  JqN5qpie   2880    1800
# 333  417   34  f1KnETPP   2560    1440
#
# [334 rows x 12 columns]

# %%
df['image'] = df['img_filename'].apply(lambda x: os.path.join('screenspotv2_image', x))

# %%
df
# Out:
#                                     img_filename                   bbox  \
# 0    pc_ede36f9b-1154-4f76-b7f8-c15d7d3f9b6e.png      [910, 78, 44, 34]
# 1    pc_5e09e8e9-7ef6-44be-ad54-aeaeac151897.png       [835, 0, 36, 30]
# 2    pc_2c6dc6ea-fd6f-4cbb-9954-2d6a68610a48.png  [1477, 450, 184, 230]
# 3    pc_b072d03a-51cb-4dd6-bdeb-152d3fd44e6b.png    [176, 202, 99, 101]
# 4    pc_ac2d2c5e-fe5a-4233-95b4-2de18ef76a9e.png     [635, 360, 42, 63]
# ..                                           ...                    ...
# 329                                pc_uuhwlx.png  [1309, 526, 114, 132]
# 330                                pc_vcud9k.png   [269, 127, 113, 132]
# 331                                pc_z7ydq8.png  [1466, 644, 147, 136]
# 332                                pc_zuyj00.png   [1744, 281, 258, 53]
# 333                                pc_aaaaaa.png    [701, 321, 417, 34]
#
#                                 instruction data_type data_source    x1   y1  \
# 0                         close this window      icon     windows   910   78
# 1                      minimize this window      icon     windows   835    0
# 2           view solitaire daily challenges      text     windows  1477  450
# 3                  open the Microsoft store      text     windows   176  202
# 4                          adjust the style      text     windows   635  360
# ..                                      ...       ...         ...   ...  ...
# 329                     open the calculator      text        shop  1309  526
# 330                      insert a new slide      text        shop   269  127
# 331      view more information about bomber      text        shop  1466  644
# 332  adjust the options of  "show previous"      icon        shop  1744  281
# 333                      enter my full name      text        shop   701  321
#
#       x2   y2        id  width  height  \
# 0     44   34  7HlAEPbj    960     540
# 1     36   30  5M0ybPZC    960     540
# 2    184  230  WHTQNchN   1920    1080
# 3     99  101  bnGg2tMZ    960     540
# 4     42   63  OkgCzIt8    960     540
# ..   ...  ...       ...    ...     ...
# 329  114  132  8gyPfDlO   2560    1440
# 330  113  132  RFq5Y47L   2880    1800
# 331  147  136  A6ctmJfK   2560    1440
# 332  258   53  JqN5qpie   2880    1800
# 333  417   34  f1KnETPP   2560    1440
#
#                                                  image
# 0    screenspotv2_image/pc_ede36f9b-1154-4f76-b7f8-...
# 1    screenspotv2_image/pc_5e09e8e9-7ef6-44be-ad54-...
# 2    screenspotv2_image/pc_2c6dc6ea-fd6f-4cbb-9954-...
# 3    screenspotv2_image/pc_b072d03a-51cb-4dd6-bdeb-...
# 4    screenspotv2_image/pc_ac2d2c5e-fe5a-4233-95b4-...
# ..                                                 ...
# 329                   screenspotv2_image/pc_uuhwlx.png
# 330                   screenspotv2_image/pc_vcud9k.png
# 331                   screenspotv2_image/pc_z7ydq8.png
# 332                   screenspotv2_image/pc_zuyj00.png
# 333                   screenspotv2_image/pc_aaaaaa.png
#
# [334 rows x 13 columns]

# %%
df.to_csv("gs://click-eval/OS-Copilot-ScreenSpot-v2/screenspot_desktop_v2.csv", index=False)
