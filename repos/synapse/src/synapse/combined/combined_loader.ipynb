# %%
from synapse.combined.combined_loader import (combined_loader, CombinedLoaderArgs)
loader_args = CombinedLoaderArgs(
  action_logs_dir="gs://induction-labs/action_capture/jeffrey/2025-06-16_101653_HTKN7",
  frame_range=(0, 1000),
  frames_zarr_path="gs://induction-labs/jeffrey/test_sft_frames.zarr/test_video.zarr"
)

# %%
frames, mouse_movements, stream_metadata = await combined_loader(loader_args)

frames[:20], mouse_movements[:20], stream_metadata
# Out:
# I0627 18:04:36.427582 1660754 google_auth_provider.cc:149] Using credentials at /home/jeffrey_inductionlabs_com/.config/gcloud/application_default_credentials.json
# I0627 18:04:36.427695 1660754 google_auth_provider.cc:156] Using OAuth2 AuthProvider
# (array([[[[62, 62, 62, ..., 53, 53, 53],
#           [62, 62, 62, ..., 53, 53, 53],
#           [62, 62, 62, ..., 53, 53, 53],
#           ...,
#           [25, 18, 21, ..., 15, 14, 11],
#           [17, 14, 17, ..., 13, 13, 10],
#           [15, 15, 16, ..., 14, 15, 13]],
#
#          [[63, 63, 63, ..., 57, 57, 57],
#           [63, 63, 63, ..., 57, 57, 57],
#           [63, 63, 63, ..., 57, 57, 57],
#           ...,
#           [42, 35, 35, ..., 19, 19, 16],
#           [34, 31, 31, ..., 19, 19, 16],
#           [32, 32, 30, ..., 20, 21, 19]],
#
#          [[53, 53, 53, ..., 42, 42, 42],
#           [53, 53, 53, ..., 42, 42, 42],
#           [53, 53, 53, ..., 42, 42, 42],
#           ...,
#           [32, 25, 26, ..., 21, 18, 15],
# ...
